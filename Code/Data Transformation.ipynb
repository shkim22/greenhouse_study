# %%
import pandas as pd

# %%
exc_ghg = pd.read_csv('total-ghg-emissions-excluding-lufc.csv')
exc_ghg2 = exc_ghg.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})
exc_ghg2
# Out:
#      Country Name Country Code  Year  Total excluding LUCF
# 0     Afghanistan          AFG  1990          1.197000e+07
# 1     Afghanistan          AFG  1991          1.220000e+07
# 2     Afghanistan          AFG  1992          1.142000e+07
# 3     Afghanistan          AFG  1993          1.150000e+07
# 4     Afghanistan          AFG  1994          1.154000e+07
# ...           ...          ...   ...                   ...
# 6144     Zimbabwe          ZWE  2015          3.070000e+07
# 6145     Zimbabwe          ZWE  2016          2.853000e+07
# 6146     Zimbabwe          ZWE  2017          2.830000e+07
# 6147     Zimbabwe          ZWE  2018          3.083000e+07
# 6148     Zimbabwe          ZWE  2019          3.053000e+07
#
# [6149 rows x 4 columns]

# %%
exc_ghg2['Year'] = pd.to_datetime(exc_ghg2['Year'], format='%Y')
exc_ghg2.tail()
# Out:
#      Country Name Country Code       Year  Total excluding LUCF
# 6144     Zimbabwe          ZWE 2015-01-01          3.070000e+07
# 6145     Zimbabwe          ZWE 2016-01-01          2.853000e+07
# 6146     Zimbabwe          ZWE 2017-01-01          2.830000e+07
# 6147     Zimbabwe          ZWE 2018-01-01          3.083000e+07
# 6148     Zimbabwe          ZWE 2019-01-01          3.053000e+07

# %%
ghg = pd.read_csv('total-ghg-emissions.csv')
ghg2= ghg.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})
ghg
# Out:
#            Entity Code  Year  Total including LUCF
# 0     Afghanistan  AFG  1990          9.580000e+06
# 1     Afghanistan  AFG  1991          9.810000e+06
# 2     Afghanistan  AFG  1992          9.030000e+06
# 3     Afghanistan  AFG  1993          9.110000e+06
# 4     Afghanistan  AFG  1994          9.150000e+06
# ...           ...  ...   ...                   ...
# 6144     Zimbabwe  ZWE  2015          4.230000e+07
# 6145     Zimbabwe  ZWE  2016          1.159200e+08
# 6146     Zimbabwe  ZWE  2017          1.155900e+08
# 6147     Zimbabwe  ZWE  2018          1.182200e+08
# 6148     Zimbabwe  ZWE  2019          1.179600e+08
#
# [6149 rows x 4 columns]

# %%
ghg2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Total including LUCF'], dtype='object')

# %%
ghg2['Year'] = pd.to_datetime(ghg2['Year'], format='%Y')
ghg2.tail()
# Out:
#      Country Name Country Code       Year  Total including LUCF
# 6144     Zimbabwe          ZWE 2015-01-01          4.230000e+07
# 6145     Zimbabwe          ZWE 2016-01-01          1.159200e+08
# 6146     Zimbabwe          ZWE 2017-01-01          1.155900e+08
# 6147     Zimbabwe          ZWE 2018-01-01          1.182200e+08
# 6148     Zimbabwe          ZWE 2019-01-01          1.179600e+08

# %%
popu = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_4902028.csv')
popu
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
#melt function

def melt (df, col_vals, key, value):
    assert type (df) is pd.DataFrame
    keep_vars = df.columns.difference(col_vals)
    melted_sections = []
    for c in col_vals:
        melted_c = df[keep_vars].copy()
        melted_c[key] = c
        melted_c[value] = df[c]
        melted_sections.append(melted_c)
    melted = pd.concat(melted_sections)
    return melted

# %%
#transformation here
display(popu)

popu_m = melt(popu, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='population')
print("=== melt(popu_m) ===")
display(popu_m)

# table4b = pd.read_csv('table4b.csv')
# print("\n=== table4b ===")
# display(table4b)

# m_4b = melt(table4b, col_vals=['1999', '2000'], key='year', value='population')
# print("=== melt(table4b) ===")
# display(m_4b)

# m_4 = pd.merge(m_4a, m_4b, on=['country', 'year'])
# print ("\n=== inner-join(melt(table4a), melt (table4b)) ===")
# display(m_4)

# m_4['year'] = m_4['year'].apply (int)

# table1 = pd.read_csv('table1.csv')
# print ("=== table1 (target solution) ===")
# display(table1)
# assert tibbles_are_equivalent(table1, m_4)
# print ("\n(Passed.)")
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
popu_m2 = popu_m[(popu_m['Year'] >= '1989-12-01') & (popu_m['Year'] < '2019-01-01')]
#df[(df['date'] > '2013-01-01') & (df['date'] < '2013-02-01')]
popu_m2.tail()
# Out:
#     Country Code  Country Name Indicator Code     Indicator Name  Year  \
# 261          XKX        Kosovo    SP.POP.TOTL  Population, total  2019
# 262          YEM   Yemen, Rep.    SP.POP.TOTL  Population, total  2019
# 263          ZAF  South Africa    SP.POP.TOTL  Population, total  2019
# 264          ZMB        Zambia    SP.POP.TOTL  Population, total  2019
# 265          ZWE      Zimbabwe    SP.POP.TOTL  Population, total  2019
#
#      population
# 261   1788878.0
# 262  31546691.0
# 263  58087055.0
# 264  18380477.0
# 265  15354608.0

# %%
popu_m2['Year'] = pd.to_datetime(popu_m2['Year'], format='%Y')
popu_m2
# Out:
# /var/folders/tz/m1h5fby16m98grm9tm4346100000gn/T/ipykernel_32082/1055589015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popu_m2['Year'] = pd.to_datetime(popu_m2['Year'], format='%Y')
#     Country Code                 Country Name Indicator Code  \
# 0            ABW                        Aruba    SP.POP.TOTL
# 1            AFE  Africa Eastern and Southern    SP.POP.TOTL
# 2            AFG                  Afghanistan    SP.POP.TOTL
# 3            AFW   Africa Western and Central    SP.POP.TOTL
# 4            AGO                       Angola    SP.POP.TOTL
# ..           ...                          ...            ...
# 261          XKX                       Kosovo    SP.POP.TOTL
# ...

# %%
popu_m2 = popu_m2.drop('Indicator Name', axis='columns')
popu_m2 = popu_m2.drop('Indicator Code', axis='columns')
popu_m2
#popu.drop('Indicator Code')
# Out:
#     Country Code                 Country Name       Year   population
# 0            ABW                        Aruba 1990-01-01      65712.0
# 1            AFE  Africa Eastern and Southern 1990-01-01  309890664.0
# 2            AFG                  Afghanistan 1990-01-01   10694796.0
# 3            AFW   Africa Western and Central 1990-01-01  206739024.0
# 4            AGO                       Angola 1990-01-01   11828638.0
# ..           ...                          ...        ...          ...
# 261          XKX                       Kosovo 2019-01-01    1788878.0
# 262          YEM                  Yemen, Rep. 2019-01-01   31546691.0
# 263          ZAF                 South Africa 2019-01-01   58087055.0
# 264          ZMB                       Zambia 2019-01-01   18380477.0
# 265          ZWE                     Zimbabwe 2019-01-01   15354608.0
#
# [7980 rows x 4 columns]

# %%
ghg2
# Out:
#      Country Name Country Code       Year  Total including LUCF
# 0     Afghanistan          AFG 1990-01-01          9.580000e+06
# 1     Afghanistan          AFG 1991-01-01          9.810000e+06
# 2     Afghanistan          AFG 1992-01-01          9.030000e+06
# 3     Afghanistan          AFG 1993-01-01          9.110000e+06
# 4     Afghanistan          AFG 1994-01-01          9.150000e+06
# ...           ...          ...        ...                   ...
# 6144     Zimbabwe          ZWE 2015-01-01          4.230000e+07
# 6145     Zimbabwe          ZWE 2016-01-01          1.159200e+08
# 6146     Zimbabwe          ZWE 2017-01-01          1.155900e+08
# 6147     Zimbabwe          ZWE 2018-01-01          1.182200e+08
# 6148     Zimbabwe          ZWE 2019-01-01          1.179600e+08
#
# [6149 rows x 4 columns]

# %%
combined1 = pd.merge(popu_m2,ghg2, on=['Country Name','Country Code','Year'], how='outer')
# m_4 = pd.merge(m_4a, m_4b, on=['country', 'year'])
# combined1.to_csv('combined1.csv')
# combined1.groupby('Country Name').apply(print)

# %%
combined1
# Out:
#      Country Code                 Country Name       Year   population  \
# 0             ABW                        Aruba 1990-01-01      65712.0
# 1             AFE  Africa Eastern and Southern 1990-01-01  309890664.0
# 2             AFG                  Afghanistan 1990-01-01   10694796.0
# 3             AFW   Africa Western and Central 1990-01-01  206739024.0
# 4             AGO                       Angola 1990-01-01   11828638.0
# ...           ...                          ...        ...          ...
# 9085          YEM                        Yemen 2015-01-01          NaN
# 9086          YEM                        Yemen 2016-01-01          NaN
# 9087          YEM                        Yemen 2017-01-01          NaN
# 9088          YEM                        Yemen 2018-01-01          NaN
# 9089          YEM                        Yemen 2019-01-01          NaN
#
#       Total including LUCF
# 0                      NaN
# 1                      NaN
# 2             9.580000e+06
# ...

# %%
combined1.to_csv('combined1.csv')

# %%
combined1.groupby('Country Name').apply(print)
# Out:
#      Country Code Country Name       Year  population  Total including LUCF
# 2             AFG  Afghanistan 1990-01-01  10694796.0          9.580000e+06
# 268           AFG  Afghanistan 1991-01-01  10745167.0          9.810000e+06
# 534           AFG  Afghanistan 1992-01-01  12057433.0          9.030000e+06
# 800           AFG  Afghanistan 1993-01-01  14003760.0          9.110000e+06
# 1066          AFG  Afghanistan 1994-01-01  15455555.0          9.150000e+06
# 1332          AFG  Afghanistan 1995-01-01  16418912.0          9.580000e+06
# 1598          AFG  Afghanistan 1996-01-01  17106595.0          1.061000e+07
# 1864          AFG  Afghanistan 1997-01-01  17788819.0          1.158000e+07
# 2130          AFG  Afghanistan 1998-01-01  18493132.0          1.240000e+07
# 2396          AFG  Afghanistan 1999-01-01  19262847.0          1.328000e+07
# 2662          AFG  Afghanistan 2000-01-01  19542982.0          1.150000e+07
# ...

# %% [markdown]
# ## ----------

# %%
#need to be melted

death_rate_from_air_pollution = pd.read_csv('death-rate-from-air-pollution-per-100000.csv')

age_dependency_ratio = pd.read_csv('Age dependency ratio.csv')
agricultural_land = pd.read_csv('Agricultural Land (% of land area).csv')
air_transport = pd.read_csv('air transport cargo.csv')
airline_travel = pd.read_csv('Airline travel 1970-2020.csv')
birth_rate = pd.read_csv('Birth rate per 1000 people.csv')
exports = pd.read_csv('Exports of goods and services Current US$.csv')
fertility_rate = pd.read_csv('Fertility rate.csv')
gdp_current = pd.read_csv('GDP Current US$.csv')
gdp_growth = pd.read_csv('GDP Growth %.csv')
labor_force = pd.read_csv('labor force.csv')
life_expectancy = pd.read_csv('Life expectancy at birth.csv')
manufacturing = pd.read_csv('Manufacturing value added current US$.csv')
natural_resources = pd.read_csv('Natural resources rents (% of GDP) 1970-2021.csv')
patent_applications = pd.read_csv('Patent applications (residents).csv')
unemployment = pd.read_csv('Unemployment % of total labor force.csv')

#no need to melt
cross_country_literacy = pd.read_csv('cross-country-literacy-rates.csv')
energy_use = pd.read_csv('energy use per person.csv')

new_vehicle = pd.read_csv('new vehicle registrations by type 2000-2020.csv')
researchers = pd.read_csv('researchers-in-rd-per-million-people.csv')
share_of_electric_vehicle = pd.read_csv('share of new electric vehicles or hybrid registrations 2001-2020.csv')
total_expenditure_on_education = pd.read_csv('total-government-expenditure-on-education-gdp.csv')

# %%
agricultural_land.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
#transformation here
#display(age_dependency_ratio)

age_dependency_ratio_m = melt(age_dependency_ratio, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='age_dependency_ratio')
#print("=== melt(age_dependency_ratio) ===")
#display(age_dependency_ratio_m)

age_dependency_ratio_m = age_dependency_ratio_m.drop('Indicator Name', axis='columns')
age_dependency_ratio_m = age_dependency_ratio_m.drop('Indicator Code', axis='columns')


age_dependency_ratio_m['Year'] = pd.to_datetime(age_dependency_ratio_m['Year'], format='%Y')
age_dependency_ratio_m = age_dependency_ratio_m[(age_dependency_ratio_m['Year'] >= '1989-12-01') & (age_dependency_ratio_m['Year'] < '2019-01-01')]
age_dependency_ratio_m
# Out:
#     Country Code                 Country Name       Year  age_dependency_ratio
# 0            ABW                        Aruba 1990-01-01             49.957783
# 1            AFE  Africa Eastern and Southern 1990-01-01             94.580170
# 2            AFG                  Afghanistan 1990-01-01             98.890488
# 3            AFW   Africa Western and Central 1990-01-01             94.979236
# 4            AGO                       Angola 1990-01-01             94.863094
# ..           ...                          ...        ...                   ...
# 261          XKX                       Kosovo 2018-01-01             48.883879
# 262          YEM                  Yemen, Rep. 2018-01-01             77.198481
# 263          ZAF                 South Africa 2018-01-01             52.754906
# 264          ZMB                       Zambia 2018-01-01             85.838977
# 265          ZWE                     Zimbabwe 2018-01-01             82.123347
#
# [7714 rows x 4 columns]

# %%
agricultural_land_m = melt(agricultural_land, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='agricultural_land')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

agricultural_land_m = agricultural_land_m.drop('Indicator Name', axis='columns')
agricultural_land_m = agricultural_land_m.drop('Indicator Code', axis='columns')


agricultural_land_m['Year'] = pd.to_datetime(agricultural_land_m['Year'], format='%Y')
agricultural_land_m = agricultural_land_m[(agricultural_land_m['Year'] >= '1989-12-01') & (agricultural_land_m['Year'] < '2019-01-01')]
agricultural_land_m
# Out:
#     Country Code                 Country Name       Year  agricultural_land
# 0            ABW                        Aruba 1990-01-01          11.111111
# 1            AFE  Africa Eastern and Southern 1990-01-01          44.077433
# 2            AFG                  Afghanistan 1990-01-01          58.322984
# 3            AFW   Africa Western and Central 1990-01-01          35.127197
# 4            AGO                       Angola 1990-01-01          36.421930
# ..           ...                          ...        ...                ...
# 261          XKX                       Kosovo 2018-01-01                NaN
# 262          YEM                  Yemen, Rep. 2018-01-01          44.419190
# 263          ZAF                 South Africa 2018-01-01          79.417850
# 264          ZMB                       Zambia 2018-01-01          32.063923
# 265          ZWE                     Zimbabwe 2018-01-01          41.876696
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

air_transport_m = melt(air_transport, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='air_transport')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

air_transport_m = air_transport_m.drop('Indicator Name', axis='columns')
air_transport_m = air_transport_m.drop('Indicator Code', axis='columns')


air_transport_m['Year'] = pd.to_datetime(air_transport_m['Year'], format='%Y')
air_transport_m = air_transport_m[(air_transport_m['Year'] >= '1989-12-01') & (air_transport_m['Year'] < '2019-01-01')]
air_transport_m
# Out:
#     Country Code                 Country Name       Year  air_transport
# 0            ABW                        Aruba 1990-01-01            NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01     652.499998
# 2            AFG                  Afghanistan 1990-01-01       9.400000
# 3            AFW   Africa Western and Central 1990-01-01     259.900005
# 4            AGO                       Angola 1990-01-01      39.900002
# ..           ...                          ...        ...            ...
# 261          XKX                       Kosovo 2018-01-01            NaN
# 262          YEM                  Yemen, Rep. 2018-01-01       3.270000
# 263          ZAF                 South Africa 2018-01-01     696.730006
# 264          ZMB                       Zambia 2018-01-01      75.077398
# 265          ZWE                     Zimbabwe 2018-01-01       0.665035
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

airline_travel_m = melt(airline_travel, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='airline_travel')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

airline_travel_m = airline_travel_m.drop('Indicator Name', axis='columns')
airline_travel_m = airline_travel_m.drop('Indicator Code', axis='columns')


airline_travel_m['Year'] = pd.to_datetime(airline_travel_m['Year'], format='%Y')
airline_travel_m = airline_travel_m[(airline_travel_m['Year'] >= '1989-12-01') & (airline_travel_m['Year'] < '2019-01-01')]
airline_travel_m
# Out:
#     Country Code                 Country Name       Year  airline_travel
# 0            ABW                        Aruba 1990-01-01             NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01    1.125740e+07
# 2            AFG                  Afghanistan 1990-01-01    2.414000e+05
# 3            AFW   Africa Western and Central 1990-01-01    3.551000e+06
# 4            AGO                       Angola 1990-01-01    4.515000e+05
# ..           ...                          ...        ...             ...
# 261          XKX                       Kosovo 2018-01-01             NaN
# 262          YEM                  Yemen, Rep. 2018-01-01    3.363100e+05
# 263          ZAF                 South Africa 2018-01-01    2.466039e+07
# 264          ZMB                       Zambia 2018-01-01    1.663314e+04
# 265          ZWE                     Zimbabwe 2018-01-01    2.825390e+05
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

birth_rate_m = melt(birth_rate, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='birth_rate')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

birth_rate_m = birth_rate_m.drop('Indicator Name', axis='columns')
birth_rate_m = birth_rate_m.drop('Indicator Code', axis='columns')


birth_rate_m['Year'] = pd.to_datetime(birth_rate_m['Year'], format='%Y')
birth_rate_m = birth_rate_m[(birth_rate_m['Year'] >= '1989-12-01') & (birth_rate_m['Year'] < '2019-01-01')]
birth_rate_m
# Out:
#     Country Code                 Country Name       Year  birth_rate
# 0            ABW                        Aruba 1990-01-01   18.662000
# 1            AFE  Africa Eastern and Southern 1990-01-01   44.230719
# 2            AFG                  Afghanistan 1990-01-01   51.423000
# 3            AFW   Africa Western and Central 1990-01-01   44.676194
# 4            AGO                       Angola 1990-01-01   51.344000
# ..           ...                          ...        ...         ...
# 261          XKX                       Kosovo 2018-01-01   12.094000
# 262          YEM                  Yemen, Rep. 2018-01-01   32.305000
# 263          ZAF                 South Africa 2018-01-01   21.137000
# 264          ZMB                       Zambia 2018-01-01   36.040000
# 265          ZWE                     Zimbabwe 2018-01-01   32.074000
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

exports_m = melt(exports, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='exports')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

exports_m = exports_m.drop('Indicator Name', axis='columns')
exports_m = exports_m.drop('Indicator Code', axis='columns')


exports_m['Year'] = pd.to_datetime(exports_m['Year'], format='%Y')
exports_m = exports_m[(exports_m['Year'] >= '1989-12-01') & (exports_m['Year'] < '2019-01-01')]
exports_m
# Out:
#     Country Code                 Country Name       Year       exports
# 0            ABW                        Aruba 1990-01-01           NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01  5.219403e+10
# 2            AFG                  Afghanistan 1990-01-01           NaN
# 3            AFW   Africa Western and Central 1990-01-01  3.096515e+10
# 4            AGO                       Angola 1990-01-01           NaN
# ..           ...                          ...        ...           ...
# 261          XKX                       Kosovo 2018-01-01  2.288980e+09
# 262          YEM                  Yemen, Rep. 2018-01-01  1.308592e+09
# 263          ZAF                 South Africa 2018-01-01  1.113970e+11
# 264          ZMB                       Zambia 2018-01-01  9.987197e+09
# 265          ZWE                     Zimbabwe 2018-01-01  8.936585e+09
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

fertility_rate_m = melt(fertility_rate, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='fertility_rate')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

fertility_rate_m = fertility_rate_m.drop('Indicator Name', axis='columns')
fertility_rate_m = fertility_rate_m.drop('Indicator Code', axis='columns')


fertility_rate_m['Year'] = pd.to_datetime(fertility_rate_m['Year'], format='%Y')
fertility_rate_m = fertility_rate_m[(fertility_rate_m['Year'] >= '1989-12-01') & (fertility_rate_m['Year'] < '2019-01-01')]
fertility_rate_m
# Out:
#     Country Code                 Country Name       Year  fertility_rate
# 0            ABW                        Aruba 1990-01-01        2.303000
# 1            AFE  Africa Eastern and Southern 1990-01-01        6.166608
# 2            AFG                  Afghanistan 1990-01-01        7.565000
# 3            AFW   Africa Western and Central 1990-01-01        6.518278
# 4            AGO                       Angola 1990-01-01        7.272000
# ..           ...                          ...        ...             ...
# 261          XKX                       Kosovo 2018-01-01        1.605000
# 262          YEM                  Yemen, Rep. 2018-01-01        4.043000
# 263          ZAF                 South Africa 2018-01-01        2.418000
# 264          ZMB                       Zambia 2018-01-01        4.536000
# 265          ZWE                     Zimbabwe 2018-01-01        3.659000
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

gdp_current_m = melt(gdp_current, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='gdp_current')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

gdp_current_m = gdp_current_m.drop('Indicator Name', axis='columns')
gdp_current_m = gdp_current_m.drop('Indicator Code', axis='columns')


gdp_current_m['Year'] = pd.to_datetime(gdp_current_m['Year'], format='%Y')
gdp_current_m = gdp_current_m[(gdp_current_m['Year'] >= '1989-12-01') & (gdp_current_m['Year'] < '2019-01-01')]
gdp_current_m
# Out:
#     Country Code                 Country Name       Year   gdp_current
# 0            ABW                        Aruba 1990-01-01  7.648045e+08
# 1            AFE  Africa Eastern and Southern 1990-01-01  2.532350e+11
# 2            AFG                  Afghanistan 1990-01-01           NaN
# 3            AFW   Africa Western and Central 1990-01-01  1.218020e+11
# 4            AGO                       Angola 1990-01-01  1.122876e+10
# ..           ...                          ...        ...           ...
# 261          XKX                       Kosovo 2018-01-01  7.878509e+09
# 262          YEM                  Yemen, Rep. 2018-01-01  2.160616e+10
# 263          ZAF                 South Africa 2018-01-01  4.041600e+11
# 264          ZMB                       Zambia 2018-01-01  2.631159e+10
# 265          ZWE                     Zimbabwe 2018-01-01  3.415607e+10
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

gdp_growth_m = melt(gdp_growth, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='gdp_growth')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

gdp_growth_m = gdp_growth_m.drop('Indicator Name', axis='columns')
gdp_growth_m = gdp_growth_m.drop('Indicator Code', axis='columns')


gdp_growth_m['Year'] = pd.to_datetime(gdp_growth_m['Year'], format='%Y')
gdp_growth_m = gdp_growth_m[(gdp_growth_m['Year'] >= '1989-12-01') & (gdp_growth_m['Year'] < '2019-01-01')]
gdp_growth_m
# Out:
#     Country Code                 Country Name       Year  gdp_growth
# 0            ABW                        Aruba 1990-01-01    3.961402
# 1            AFE  Africa Eastern and Southern 1990-01-01   -0.032630
# 2            AFG                  Afghanistan 1990-01-01         NaN
# 3            AFW   Africa Western and Central 1990-01-01    6.600199
# 4            AGO                       Angola 1990-01-01   -3.450099
# ..           ...                          ...        ...         ...
# 261          XKX                       Kosovo 2018-01-01    3.406631
# 262          YEM                  Yemen, Rep. 2018-01-01    0.752448
# 263          ZAF                 South Africa 2018-01-01    1.522329
# 264          ZMB                       Zambia 2018-01-01    4.034494
# 265          ZWE                     Zimbabwe 2018-01-01    5.009867
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

labor_force_m = melt(labor_force, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='labor_force')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

labor_force_m = labor_force_m.drop('Indicator Name', axis='columns')
labor_force_m = labor_force_m.drop('Indicator Code', axis='columns')


labor_force_m['Year'] = pd.to_datetime(labor_force_m['Year'], format='%Y')
labor_force_m = labor_force_m[(labor_force_m['Year'] >= '1989-12-01') & (labor_force_m['Year'] < '2019-01-01')]
labor_force_m
# Out:
#     Country Code                 Country Name       Year  labor_force
# 0            ABW                        Aruba 1990-01-01          NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01  121955049.0
# 2            AFG                  Afghanistan 1990-01-01    2641964.0
# 3            AFW   Africa Western and Central 1990-01-01   74675274.0
# 4            AGO                       Angola 1990-01-01    4889409.0
# ..           ...                          ...        ...          ...
# 261          XKX                       Kosovo 2018-01-01          NaN
# 262          YEM                  Yemen, Rep. 2018-01-01    6894546.0
# 263          ZAF                 South Africa 2018-01-01   23771538.0
# 264          ZMB                       Zambia 2018-01-01    5789287.0
# 265          ZWE                     Zimbabwe 2018-01-01    5770226.0
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

life_expectancy_m = melt(life_expectancy, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='life_expectancy')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

life_expectancy_m = life_expectancy_m.drop('Indicator Name', axis='columns')
life_expectancy_m = life_expectancy_m.drop('Indicator Code', axis='columns')


life_expectancy_m['Year'] = pd.to_datetime(life_expectancy_m['Year'], format='%Y')
life_expectancy_m = life_expectancy_m[(life_expectancy_m['Year'] >= '1989-12-01') & (life_expectancy_m['Year'] < '2019-01-01')]
life_expectancy_m
# Out:
#     Country Code                 Country Name       Year  life_expectancy
# 0            ABW                        Aruba 1990-01-01        73.076000
# 1            AFE  Africa Eastern and Southern 1990-01-01        50.607728
# 2            AFG                  Afghanistan 1990-01-01        45.967000
# 3            AFW   Africa Western and Central 1990-01-01        48.650003
# 4            AGO                       Angola 1990-01-01        41.893000
# ..           ...                          ...        ...              ...
# 261          XKX                       Kosovo 2018-01-01        78.696000
# 262          YEM                  Yemen, Rep. 2018-01-01        64.575000
# 263          ZAF                 South Africa 2018-01-01        65.674000
# 264          ZMB                       Zambia 2018-01-01        62.342000
# 265          ZWE                     Zimbabwe 2018-01-01        61.414000
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

manufacturing_m = melt(manufacturing, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='manufacturing')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

manufacturing_m = manufacturing_m.drop('Indicator Name', axis='columns')
manufacturing_m = manufacturing_m.drop('Indicator Code', axis='columns')


manufacturing_m['Year'] = pd.to_datetime(manufacturing_m['Year'], format='%Y')
manufacturing_m = manufacturing_m[(manufacturing_m['Year'] >= '1989-12-01') & (manufacturing_m['Year'] < '2019-01-01')]
manufacturing_m
# Out:
#     Country Code                 Country Name       Year  manufacturing
# 0            ABW                        Aruba 1990-01-01            NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01   4.234682e+10
# 2            AFG                  Afghanistan 1990-01-01            NaN
# 3            AFW   Africa Western and Central 1990-01-01   1.819253e+10
# 4            AGO                       Angola 1990-01-01            NaN
# ..           ...                          ...        ...            ...
# 261          XKX                       Kosovo 2018-01-01   1.034250e+09
# 262          YEM                  Yemen, Rep. 2018-01-01            NaN
# 263          ZAF                 South Africa 2018-01-01   5.048741e+10
# 264          ZMB                       Zambia 2018-01-01   1.801756e+09
# 265          ZWE                     Zimbabwe 2018-01-01   4.671914e+09
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

natural_resources_m = melt(natural_resources, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='natural_resources')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

natural_resources_m = natural_resources_m.drop('Indicator Name', axis='columns')
natural_resources_m = natural_resources_m.drop('Indicator Code', axis='columns')


natural_resources_m['Year'] = pd.to_datetime(natural_resources_m['Year'], format='%Y')
natural_resources_m = natural_resources_m[(natural_resources_m['Year'] >= '1989-12-01') & (natural_resources_m['Year'] < '2019-01-01')]
natural_resources_m
# Out:
#     Country Code                 Country Name       Year  natural_resources
# 0            ABW                        Aruba 1990-01-01           0.001552
# 1            AFE  Africa Eastern and Southern 1990-01-01           7.289594
# 2            AFG                  Afghanistan 1990-01-01                NaN
# 3            AFW   Africa Western and Central 1990-01-01          17.436494
# 4            AGO                       Angola 1990-01-01          28.938576
# ..           ...                          ...        ...                ...
# 261          XKX                       Kosovo 2018-01-01           0.572220
# 262          YEM                  Yemen, Rep. 2018-01-01           4.609356
# 263          ZAF                 South Africa 2018-01-01           3.397165
# 264          ZMB                       Zambia 2018-01-01          11.548952
# 265          ZWE                     Zimbabwe 2018-01-01           6.085075
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

patent_applications_m = melt(patent_applications, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='patent_applications')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

patent_applications_m = patent_applications_m.drop('Indicator Name', axis='columns')
patent_applications_m = patent_applications_m.drop('Indicator Code', axis='columns')


patent_applications_m['Year'] = pd.to_datetime(patent_applications_m['Year'], format='%Y')
patent_applications_m = patent_applications_m[(patent_applications_m['Year'] >= '1989-12-01') & (patent_applications_m['Year'] < '2019-01-01')]
patent_applications_m
# Out:
#     Country Code                 Country Name       Year  patent_applications
# 0            ABW                        Aruba 1990-01-01                  NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01                  NaN
# 2            AFG                  Afghanistan 1990-01-01                  NaN
# 3            AFW   Africa Western and Central 1990-01-01                  NaN
# 4            AGO                       Angola 1990-01-01                  NaN
# ..           ...                          ...        ...                  ...
# 261          XKX                       Kosovo 2018-01-01                  NaN
# 262          YEM                  Yemen, Rep. 2018-01-01                  NaN
# 263          ZAF                 South Africa 2018-01-01                657.0
# 264          ZMB                       Zambia 2018-01-01                 11.0
# 265          ZWE                     Zimbabwe 2018-01-01                  NaN
#
# [7714 rows x 4 columns]

# %%
#transformation here
#display(agricultural_land)

unemployment_m = melt(unemployment, col_vals=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], key='Year', value='unemployment')
#print("=== melt(agricultural_land) ===")
#display(agricultural_land_m)

unemployment_m = unemployment_m.drop('Indicator Name', axis='columns')
unemployment_m = unemployment_m.drop('Indicator Code', axis='columns')


unemployment_m['Year'] = pd.to_datetime(unemployment_m['Year'], format='%Y')
unemployment_m = unemployment_m[(unemployment_m['Year'] >= '1989-12-01') & (unemployment_m['Year'] < '2019-01-01')]
unemployment_m
# Out:
#     Country Code                 Country Name       Year  unemployment
# 0            ABW                        Aruba 1990-01-01           NaN
# 1            AFE  Africa Eastern and Southern 1990-01-01           NaN
# 2            AFG                  Afghanistan 1990-01-01           NaN
# 3            AFW   Africa Western and Central 1990-01-01           NaN
# 4            AGO                       Angola 1990-01-01           NaN
# ..           ...                          ...        ...           ...
# 261          XKX                       Kosovo 2018-01-01     27.760000
# 262          YEM                  Yemen, Rep. 2018-01-01           NaN
# 263          ZAF                 South Africa 2018-01-01     24.219999
# 264          ZMB                       Zambia 2018-01-01      5.030000
# 265          ZWE                     Zimbabwe 2018-01-01           NaN
#
# [7714 rows x 4 columns]

# %%
data_frames2 = [age_dependency_ratio_m, 
                agricultural_land_m, 
                air_transport_m,
                airline_travel_m,
                birth_rate_m,
                exports_m,
                fertility_rate_m, 
                gdp_current_m, 
                gdp_growth_m, 
                labor_force_m,
                life_expectancy_m,
                manufacturing_m,
                natural_resources_m,
                patent_applications_m,
                unemployment_m,
               ]

# %%
df_merged2 = reduce(lambda  left,right: pd.merge(left,right,on=['Country Name','Country Code','Year'],
                                            how='outer'), data_frames2)
# if you want to fill the values that don't exist in the lines of merged dataframe simply fill with required strings as

df_merged2 = reduce(lambda  left,right: pd.merge(left,right,on=['Country Name','Country Code','Year'],
                                            how='outer'), data_frames2).fillna('void')

df_merged2
# Out:
#      Country Code                 Country Name       Year  \
# 0             ABW                        Aruba 1990-01-01
# 1             AFE  Africa Eastern and Southern 1990-01-01
# 2             AFG                  Afghanistan 1990-01-01
# 3             AFW   Africa Western and Central 1990-01-01
# 4             AGO                       Angola 1990-01-01
# ...           ...                          ...        ...
# 7709          XKX                       Kosovo 2018-01-01
# 7710          YEM                  Yemen, Rep. 2018-01-01
# 7711          ZAF                 South Africa 2018-01-01
# 7712          ZMB                       Zambia 2018-01-01
# 7713          ZWE                     Zimbabwe 2018-01-01
#
#      age_dependency_ratio agricultural_land air_transport airline_travel  \
# 0               49.957783         11.111111          void           void
# 1                94.58017         44.077433    652.499998     11257400.0
# ...

# %%
# age_dependency_ratio = pd.read_csv('Age dependency ratio.csv')
# agricultural_land = pd.read_csv('Agricultural Land (% of land area).csv')
# air_transport = pd.read_csv('air transport cargo.csv')
# airline_travel = pd.read_csv('Airline travel 1970-2020.csv')
# birth_rate = pd.read_csv('Birth rate per 1000 people.csv')
# exports = pd.read_csv('Exports of goods and services Current US$.csv')
# fertility_rate = pd.read_csv('Fertility rate.csv')
# gdp_current = pd.read_csv('GDP Current US$.csv')
# gdp_growth = pd.read_csv('GDP Growth %.csv')
# labor_force = pd.read_csv('labor force.csv')
# life_expectancy = pd.read_csv('Life expectancy at birth.csv')
# manufacturing = pd.read_csv('Manufacturing value added current US$.csv')
# natural_resources = pd.read_csv('Natural resources rents (% of GDP) 1970-2021.csv')
# patent_applications = pd.read_csv('Patent applications (residents).csv')
# unemployment = pd.read_csv('Unemployment % of total labor force.csv')


# #no need to melt
# cross_country_literacy = pd.read_csv('cross-country-literacy-rates.csv')
# energy_use = pd.read_csv('energy use per person.csv')
# new_vehicle = pd.read_csv('new vehicle registrations by type 2000-2020.csv')
# researchers = pd.read_csv('researchers-in-rd-per-million-people.csv')
# share_of_electric_vehicle = pd.read_csv('share of new electric vehicles or hybrid registrations 2001-2020.csv')
# total_expenditure_on_education = pd.read_csv('total-government-expenditure-on-education-gdp.csv')

# %%
cross_country_literacy.groupby('Entity').apply(print)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1979
# 1  Afghanistan  AFG  2011
# 2  Afghanistan  AFG  2015
#
#    Literacy rates (World Bank, CIA World Factbook, and other sources)
# 0                                          18.157681
# 1                                          31.741119
# 2                                          38.168041
#     Entity Code  Year  \
# 3  Albania  ALB  2001
# 4  Albania  ALB  2008
# 5  Albania  ALB  2011
# 6  Albania  ALB  2012
# 7  Albania  ALB  2015
#
#    Literacy rates (World Bank, CIA World Factbook, and other sources)
# 3                                          98.712982
# 4                                          95.938637
# 5                                          96.845299
# 6                                          97.246971
# 7                                          97.553902
#      Entity Code  Year  \
# 8   Algeria  DZA  1987
# 9   Algeria  DZA  2002
# 10  Algeria  DZA  2006
# 11  Algeria  DZA  2008
# ...

# %%
#cross_country_literacy['Year'] = pd.to_datetime(cross_country_literacy['Year'], format='%Y')
#cross_country_literacy = cross_country_literacy[(cross_country_literacy['Year'] >= '1989-12-01') & (cross_country_literacy['Year'] < '2019-01-01')]
cross_country_literacy= cross_country_literacy.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})
cross_country_literacy
# Out:
#      Country Name Country Code  Year  \
# 0     Afghanistan          AFG  1979
# 1     Afghanistan          AFG  2011
# 2     Afghanistan          AFG  2015
# 3         Albania          ALB  2001
# 4         Albania          ALB  2008
# ...           ...          ...   ...
# 1418       Zambia          ZMB  2015
# 1419     Zimbabwe          ZWE  1982
# 1420     Zimbabwe          ZWE  1992
# 1421     Zimbabwe          ZWE  2011
# 1422     Zimbabwe          ZWE  2015
#
#       Literacy rates (World Bank, CIA World Factbook, and other sources)
# 0                                             18.157681
# 1                                             31.741119
# 2                                             38.168041
# 3                                             98.712982
# 4                                             95.938637
# ...                                                 ...
# 1418                                          85.117264
# ...

# %%
energy_use['Year'] = pd.to_datetime(energy_use['Year'], format='%Y')
energy_use = energy_use[(energy_use['Year'] >= '1989-12-01') & (energy_use['Year'] < '2019-01-01')]
energy_use= energy_use.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})

energy_use
# Out:
#       Country Name Country Code       Year  \
# 10     Afghanistan          AFG 1990-01-01
# 11     Afghanistan          AFG 1991-01-01
# 12     Afghanistan          AFG 1992-01-01
# 13     Afghanistan          AFG 1993-01-01
# 14     Afghanistan          AFG 1994-01-01
# ...            ...          ...        ...
# 10235     Zimbabwe          ZWE 2014-01-01
# 10236     Zimbabwe          ZWE 2015-01-01
# 10237     Zimbabwe          ZWE 2016-01-01
# 10238     Zimbabwe          ZWE 2017-01-01
# 10239     Zimbabwe          ZWE 2018-01-01
#
#        Primary energy consumption per capita (kWh/person)
# 10                                            2968.31600
# 11                                            1293.86190
# 12                                             760.34247
# 13                                             650.20715
# 14                                             570.40330
# ...                                                  ...
# ...

# %%
new_vehicle['Year'] = pd.to_datetime(new_vehicle['Year'], format='%Y')
new_vehicle = new_vehicle[(new_vehicle['Year'] >= '1989-12-01') & (new_vehicle['Year'] < '2019-01-01')]
new_vehicle= new_vehicle.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})

new_vehicle
# Out:
#        Country Name Country Code       Year  battery_electric_number  \
# 0           Austria          AUT 2001-01-01                      0.0
# 1           Austria          AUT 2002-01-01                      1.0
# 2           Austria          AUT 2003-01-01                      0.0
# 3           Austria          AUT 2004-01-01                      0.0
# 4           Austria          AUT 2005-01-01                      0.0
# ..              ...          ...        ...                      ...
# 303  United Kingdom          GBR 2014-01-01                   8067.0
# 304  United Kingdom          GBR 2015-01-01                  10054.0
# 305  United Kingdom          GBR 2016-01-01                  10276.0
# 306  United Kingdom          GBR 2017-01-01                  13576.0
# 307  United Kingdom          GBR 2018-01-01                  14944.0
#
#      plugin_hybrid_number  full_mild_hybrid_number  petrol_number  \
# 0                     0.0                39.000000   1.007540e+05
# ...

# %%
researchers['Year'] = pd.to_datetime(researchers['Year'], format='%Y')
researchers = researchers[(researchers['Year'] >= '1989-12-01') & (researchers['Year'] < '2019-01-01')]
researchers= researchers.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})
researchers
# Out:
#         Country Name Country Code       Year  \
# 0            Albania          ALB 2008-01-01
# 1            Algeria          DZA 2005-01-01
# 2            Algeria          DZA 2017-01-01
# 3     American Samoa          ASM 2002-01-01
# 4     American Samoa          ASM 2003-01-01
# ...              ...          ...        ...
# 1683          Zambia          ZMB 1997-01-01
# 1684          Zambia          ZMB 1998-01-01
# 1685          Zambia          ZMB 1999-01-01
# 1686          Zambia          ZMB 2008-01-01
# 1687        Zimbabwe          ZWE 2012-01-01
#
#       Researchers in R&D (per million people)
# 0                                  155.527832
# 1                                  168.719345
# 2                                  819.342712
# 3                                   84.631012
# 4                                  403.334228
# ...                                       ...
# 1683                                51.575352
# ...

# %%
share_of_electric_vehicle['Year'] = pd.to_datetime(share_of_electric_vehicle['Year'], format='%Y')
share_of_electric_vehicle = share_of_electric_vehicle[(share_of_electric_vehicle['Year'] >= '1989-12-01') & (share_of_electric_vehicle['Year'] < '2019-01-01')]
share_of_electric_vehicle= share_of_electric_vehicle.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})
share_of_electric_vehicle
# Out:
#        Country Name Country Code       Year  battery_electric_share  \
# 0           Austria          AUT 2001-01-01                0.000000
# 1           Austria          AUT 2002-01-01                0.000358
# 2           Austria          AUT 2003-01-01                0.000000
# 3           Austria          AUT 2004-01-01                0.000000
# 4           Austria          AUT 2005-01-01                0.000000
# ..              ...          ...        ...                     ...
# 303  United Kingdom          GBR 2014-01-01                0.325751
# 304  United Kingdom          GBR 2015-01-01                0.381773
# 305  United Kingdom          GBR 2016-01-01                0.381612
# 306  United Kingdom          GBR 2017-01-01                0.534358
# 307  United Kingdom          GBR 2018-01-01                0.631308
#
#      plugin_hybrid_share
# 0               0.000000
# 1               0.000000
# 2               0.000000
# 3               0.000000
# ...

# %%
total_expenditure_on_education['Year'] = pd.to_datetime(total_expenditure_on_education['Year'], format='%Y')
total_expenditure_on_education = total_expenditure_on_education[(total_expenditure_on_education['Year'] >= '1989-12-01') & (total_expenditure_on_education['Year'] < '2019-01-01')]
total_expenditure_on_education= total_expenditure_on_education.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})
total_expenditure_on_education
# Out:
#      Country Name Country Code       Year  \
# 8     Afghanistan          AFG 2010-01-01
# 9     Afghanistan          AFG 2011-01-01
# 10    Afghanistan          AFG 2013-01-01
# 11    Afghanistan          AFG 2014-01-01
# 12    Afghanistan          AFG 2015-01-01
# ...           ...          ...        ...
# 4590     Zimbabwe          ZWE 2014-01-01
# 4591     Zimbabwe          ZWE 2015-01-01
# 4592     Zimbabwe          ZWE 2016-01-01
# 4593     Zimbabwe          ZWE 2017-01-01
# 4594     Zimbabwe          ZWE 2018-01-01
#
#       Government expenditure on education, total (% of GDP)
# 8                                               3.47945
# 9                                               3.46201
# 10                                              3.45446
# 11                                              3.69522
# 12                                              3.25580
# ...                                                 ...
# ...

# %%
from functools import reduce
data_frames = [energy_use,
               total_expenditure_on_education, 
               share_of_electric_vehicle,
               new_vehicle, 
               researchers,
              ]
               #cross_country_literacy,]

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Country Name','Country Code','Year'],
                                            how='outer'), data_frames)

# if you want to fill the values that don't exist in the lines of merged dataframe simply fill with required strings as

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Country Name','Country Code','Year'],
                                            how='outer'), data_frames).fillna('void')

# %%
df_merged
# Out:
#                      Country Name Country Code       Year  \
# 0                     Afghanistan          AFG 1990-01-01
# 1                     Afghanistan          AFG 1991-01-01
# 2                     Afghanistan          AFG 1992-01-01
# 3                     Afghanistan          AFG 1993-01-01
# 4                     Afghanistan          AFG 1994-01-01
# ...                           ...          ...        ...
# 6886  Latin America and Caribbean         void 2005-01-01
# 6887                       Monaco          MCO 2005-01-01
# 6888                   South Asia         void 1996-01-01
# 6889          Upper middle income         void 1997-01-01
# 6890          Upper middle income         void 1998-01-01
#
#      Primary energy consumption per capita (kWh/person)  \
# 0                                              2968.316
# 1                                             1293.8619
# 2                                             760.34247
# ...

# %%
df_merged3 = pd.merge(df_merged2,df_merged, on=['Country Name','Country Code','Year'], how='outer')
# m_4 = pd.merge(m_4a, m_4b, on=['country', 'year'])
# combined1.to_csv('combined1.csv')
# combined1.groupby('Country Name').apply(print)
df_merged3
# Out:
#      Country Code                 Country Name       Year  \
# 0             ABW                        Aruba 1990-01-01
# 1             AFE  Africa Eastern and Southern 1990-01-01
# 2             AFG                  Afghanistan 1990-01-01
# 3             AFW   Africa Western and Central 1990-01-01
# 4             AGO                       Angola 1990-01-01
# ...           ...                          ...        ...
# 9513         void                  High income 1997-01-01
# 9514         void  Latin America and Caribbean 2005-01-01
# 9515         void                   South Asia 1996-01-01
# 9516         void          Upper middle income 1997-01-01
# 9517         void          Upper middle income 1998-01-01
#
#      age_dependency_ratio agricultural_land air_transport airline_travel  \
# 0               49.957783         11.111111          void           void
# 1                94.58017         44.077433    652.499998     11257400.0
# ...

# %%
combined3 = pd.merge(df_merged3,combined1, on=['Country Name','Country Code','Year'], how='outer')
combined3
#combined3.to_csv('combined3.csv')
# Out:
#       Country Code                   Country Name       Year  \
# 0              ABW                          Aruba 1990-01-01
# 1              AFE    Africa Eastern and Southern 1990-01-01
# 2              AFG                    Afghanistan 1990-01-01
# 3              AFW     Africa Western and Central 1990-01-01
# 4              AGO                         Angola 1990-01-01
# ...            ...                            ...        ...
# 10150          NaN  Upper-middle-income countries 2018-01-01
# 10151          NaN  Upper-middle-income countries 2019-01-01
# 10152          VEN                      Venezuela 2019-01-01
# 10153     OWID_WRL                          World 2019-01-01
# 10154          YEM                          Yemen 2019-01-01
#
#       age_dependency_ratio agricultural_land air_transport airline_travel  \
# 0                49.957783         11.111111          void           void
# 1                 94.58017         44.077433    652.499998     11257400.0
# ...

# %%
death_rate_from_air_pollution['Year'] = pd.to_datetime(death_rate_from_air_pollution['Year'], format='%Y')
death_rate_from_air_pollution= death_rate_from_air_pollution.rename(columns={'Entity': 'Country Name', 'Code': 'Country Code'})

# %%
combined4 = pd.merge(combined3,death_rate_from_air_pollution, on=['Country Name','Country Code','Year'], how='outer')
combined4
# Out:
#       Country Code                    Country Name       Year  \
# 0              ABW                           Aruba 1990-01-01
# 1              AFE     Africa Eastern and Southern 1990-01-01
# 2              AFG                     Afghanistan 1990-01-01
# 3              AFW      Africa Western and Central 1990-01-01
# 4              AGO                          Angola 1990-01-01
# ...            ...                             ...        ...
# 10880          NaN  World Bank Upper Middle Income 2015-01-01
# 10881          NaN  World Bank Upper Middle Income 2016-01-01
# 10882          NaN  World Bank Upper Middle Income 2017-01-01
# 10883          NaN  World Bank Upper Middle Income 2018-01-01
# 10884          NaN  World Bank Upper Middle Income 2019-01-01
#
#       age_dependency_ratio agricultural_land air_transport airline_travel  \
# 0                49.957783         11.111111          void           void
# ...

# %%
combined4.to_csv('combined4.csv')

# %%
combined4 = pd.read_csv('combined4.csv')
#combined4.info()

# %%
combined4 = pd.merge(combined3,death_rate_from_air_pollution, on=['Country Name','Country Code','Year'], how='outer')
#combined4.info()

# %%
exc_ghg3.info()

# %%
combined7 = pd.merge(combined4,exc_ghg2, on=['Country Name','Country Code','Year'], how='outer')
combined7

# %%
combined7.to_csv('combined7.csv')

# %%
combined7_clean = combined7.dropna()

# %%
combined7_clean
# Out:
#      Country Code          Country Name       Year age_dependency_ratio  \
# 2             AFG           Afghanistan 1990-01-01            98.890488
# 4             AGO                Angola 1990-01-01            94.863094
# 5             ALB               Albania 1990-01-01            62.078455
# 8             ARE  United Arab Emirates 1990-01-01            44.331158
# 9             ARG             Argentina 1990-01-01            64.213271
# ...           ...                   ...        ...                  ...
# 7706          VUT               Vanuatu 2018-01-01             77.12803
# 7708          WSM                 Samoa 2018-01-01            75.526073
# 7711          ZAF          South Africa 2018-01-01            52.754906
# 7712          ZMB                Zambia 2018-01-01            85.838977
# 7713          ZWE              Zimbabwe 2018-01-01            82.123347
#
#      agricultural_land air_transport airline_travel birth_rate  \
# ...

# %%
combined7_clean.isnull().sum()
# Out:
# Country Code                                                                                   0
# Country Name                                                                                   0
# Year                                                                                           0
# age_dependency_ratio                                                                           0
# agricultural_land                                                                              0
# air_transport                                                                                  0
# airline_travel                                                                                 0
# birth_rate                                                                                     0
# exports                                                                                        0
# fertility_rate                                                                                 0
# ...

# %%
combined3 = pd.merge(total_expenditure_on_education,share_of_electric_vehicle,researchers,new_vehicle, on=['Country Name','Country Code','Year'], how='outer')
# m_4 = pd.merge(m_4a, m_4b, on=['country', 'year'])
combined3

# %%
share_of_electric_vehicle

# %%
new_vehicle
